# %%
# 가상환경과 함께 설치 - anaconda prompt 설치와 동일
# !pip install folium

# pip install folium - 현재 환경에서 설치

# %%
from folium import *

# Map() 클래스 사용, location-[경도, 위도], zoom_start-확대/축소
seoul_map = Map(location=[37.55, 126.99], zoom_start=12)

# 지도를 html로 저장
seoul_map.save("./datas/seoul.html")

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium import *

# Map() 클래스 사용, location-[경도, 위도], zoom_start-확대/축소
# 지도 스타일 - tiles="스타일"
seoul_map = Map(
    location=[37.55, 126.99], 
    zoom_start=12,
    tiles = "Cartodb Positron"
)

# 지도를 html로 저장
seoul_map.save("./datas/seoul2.html")

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 공덕역 마커 표시하기

# %%
import folium

# Map 클래스 사용, location-[경도, 위도], zoom_start-확대/축소
# 지도 스타일 - tiles="스타일"
# 지도 객체 생성
seoul_map = folium.Map(
    location=[37.54322, 126.951576], 
    zoom_start=15
)

# Marker 클래스 - icon : Icon 클래스 icon 속성-'star', 'arrow-up'
# Marker 매서드 - add_to(지도 객체)
folium.Marker(
    location=[37.54322, 126.951576], 
    icon = folium.Icon(icon='arrow-down', color='green'),
    zoom_start=15
).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Map 클래스 사용, location-[경도, 위도], zoom_start-확대/축소
# 지도 스타일 - tiles="스타일"
# 지도 객체 생성
seoul_map = folium.Map(
    location=[37.54322, 126.951576], 
    zoom_start=15
)

# Marker 클래스 - icon : Icon 클래스 icon 속성-'star', 'arrow-up'
# Marker 매서드 - add_to(지도 객체)
folium.Marker(
    location=[37.54322, 126.951576], 
    icon = folium.Icon(icon='arrow-down', color='green'),
    popup = "공덕역",
    zoom_start=15
).add_to(seoul_map)

folium.CircleMarker(
    location=[37.54322, 126.951576], 
    radius = 100,  #반지름 100px
    color = "#ff0",  #16진수 - 노란색
).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
