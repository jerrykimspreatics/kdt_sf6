# %%
# pip install folium
import folium

# Map() 클래스 사용, location-[위도, 경도], zoom_start-확대/축소
seoul_map = folium.Map(location=[37.539705, 126.94604], zoom_start=12)

# locations = [
#     [37.539705, 126.94604],  #마포역
#     [37.497952, 127.027619], #강남역
#     [37.57173, 127.011069]   #동대문역
# ]

# 리스트와 딕셔너리
map_info = [
    {"location": [37.539705, 126.94604], "popup": "마포역"},
    {"location": [37.497952, 127.027619], "popup": "강남역"},
    {"location": [37.57173, 127.011069], "popup": "동대문역"},
]

for map in map_info:
    folium.Marker(
        location=map["location"], 
        popup=map["popup"],
        icon = folium.Icon(icon='arrow-down', color='blue')
    ).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e4de6cd87fea0e0d874ea5074ef568b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e4de6cd87fea0e0d874ea5074ef568b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e4de6cd87fea0e0d874ea5074ef568b = L.map(
#                 &quot;map_8e4de6cd87fea0e0d874ea5074ef568b&quot;,
#                 {
#                     center: [37.539705, 126.94604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_938958c063e9917463de6fe0c35995d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_938958c063e9917463de6fe0c35995d2.addTo(map_8e4de6cd87fea0e0d874ea5074ef568b);
#
#
#             var marker_f725e002b7cf01bd03874dc986956cd6 = L.marker(
#                 [37.539705, 126.94604],
#                 {}
#             ).addTo(map_8e4de6cd87fea0e0d874ea5074ef568b);
#
#
#             var icon_f80377f78b33936266b286ac232fc6e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f725e002b7cf01bd03874dc986956cd6.setIcon(icon_f80377f78b33936266b286ac232fc6e5);
#
#
#         var popup_7cd1a651c421180fe9047c623f9c85e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bde381ecc94bf0281d9e680e88ca503d = $(`&lt;div id=&quot;html_bde381ecc94bf0281d9e680e88ca503d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;마포역&lt;/div&gt;`)[0];
#                 popup_7cd1a651c421180fe9047c623f9c85e0.setContent(html_bde381ecc94bf0281d9e680e88ca503d);
#
#
#
#         marker_f725e002b7cf01bd03874dc986956cd6.bindPopup(popup_7cd1a651c421180fe9047c623f9c85e0)
#         ;
#
#
#
#
#             var marker_397d0e057745740ceb935fc340bda5b5 = L.marker(
#                 [37.497952, 127.027619],
#                 {}
#             ).addTo(map_8e4de6cd87fea0e0d874ea5074ef568b);
#
#
#             var icon_f70765a2d6e86c1328bfd4fb1c2b9e66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_397d0e057745740ceb935fc340bda5b5.setIcon(icon_f70765a2d6e86c1328bfd4fb1c2b9e66);
#
#
#         var popup_5d32682dd666f4977c4911f80f54ed33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5b741790b2420d8c6f2c5c8f7cab9b3 = $(`&lt;div id=&quot;html_a5b741790b2420d8c6f2c5c8f7cab9b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남역&lt;/div&gt;`)[0];
#                 popup_5d32682dd666f4977c4911f80f54ed33.setContent(html_a5b741790b2420d8c6f2c5c8f7cab9b3);
#
#
#
#         marker_397d0e057745740ceb935fc340bda5b5.bindPopup(popup_5d32682dd666f4977c4911f80f54ed33)
#         ;
#
#
#
#
#             var marker_8e396c7555840704972e3a578b588245 = L.marker(
#                 [37.57173, 127.011069],
#                 {}
#             ).addTo(map_8e4de6cd87fea0e0d874ea5074ef568b);
#
#
#             var icon_b8f8937287fc1e243782ef910a5a42b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e396c7555840704972e3a578b588245.setIcon(icon_b8f8937287fc1e243782ef910a5a42b8);
#
#
#         var popup_5142cf050ca667b2afad4c970bdf726d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b21ab768b61b6c9e56ace6f2dd862352 = $(`&lt;div id=&quot;html_b21ab768b61b6c9e56ace6f2dd862352&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동대문역&lt;/div&gt;`)[0];
#                 popup_5142cf050ca667b2afad4c970bdf726d.setContent(html_b21ab768b61b6c9e56ace6f2dd862352);
#
#
#
#         marker_8e396c7555840704972e3a578b588245.bindPopup(popup_5142cf050ca667b2afad4c970bdf726d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
